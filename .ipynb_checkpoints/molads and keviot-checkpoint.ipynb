# %% [markdown]
# # Calculates a year in the Jewish calendar

# %%
#defines functions to do math with molads

# %%
def mol_remainder_remover(mol):
    while mol[2]>=1080:
        mol[2]=mol[2]-1080
        mol[1]=mol[1]+1
    while mol[1]>=24:
        mol[1]=mol[1]-24
        mol[0]=mol[0]+1
    while mol[0]>7:
        mol[0]=mol[0]-7
    return mol

def mult_mol(mult,mol):
    mol_mult = [mol[0]*mult,mol[1]*mult,mol[2]*mult]
    return mol_remainder_remover(mol_mult)

def add_mol(mol1,mol2):
    mol_summed = [mol1[0]+mol2[0],mol1[1]+mol2[1],mol1[2]+mol2[2]]
    return mol_remainder_remover(mol_summed)

# %%
#defines basic data

# %%
baharad = [2,5,204]  #ב־ה־ר״ד
monthly_molad = [1,12,793] #א־יב־תשצ״ג
leap_years = [3,6,8,11,14,17,0] #גוחאדז״ט
count_leap = len(leap_years)
machzor_len = 19
count_peshuta = machzor_len - count_leap
months_in_machzor = (len(leap_years)*13)+((19-len(leap_years))*12)
yrp_remain = mult_mol(12,monthly_molad) #ד־ח־תת״ו
yrm_remain = mult_mol(13,monthly_molad) #ה־כא־תקפ״ט
yr_remain = [yrp_remain, yrm_remain]
machzor_remain = add_mol(mult_mol(count_leap,yrm_remain),mult_mol(count_peshuta,yrp_remain)) #ב־יו־תקצ״ה

# %%
daysorder = ['א','ב','ג','ד','ה','ו','ז']
daynames = ['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

# %%
daysorder[0]
# Out:
# 'א'

# %%
months_p1 = ['Tishrei',r'Mar\d{h}eshvan','Kislev','Tevet','Shevat','Adar','Nisan','Iyyar','Sivan','Tammuz','Av','Elul']
months_p2 = ['תשרי','מרחשון','כסלו','טבת','שבט','אדר','ניסן','אייר','סיון','תמוז','אב','אלול']
months_m1 = ['Tishrei',r'Mar\d{h}eshvan','Kislev','Tevet','Shevat','Adar I','Adar II','Nisan','Iyyar','Sivan','Tammuz','Av','Elul']
months_m2 = ['תשרי','מרחשון','כסלו','טבת','שבט','אדר א׳','אדר ב׳','ניסן','אייר','סיון','תמוז','אב','אלול']
months1 = months_p1,months_m1
months2 = months_p2,months_m2
months_hebcal = ['Tishrei', 'Cheshvan', 'Kislev', 'Tevet', 'Shvat', 'Adar1', 'Adar2', 'Nisan', 'Iyyar', 'Sivan', 'Tamuz', 'Av', 'Elul']

# %%
def leap_checker(year):
    if year%19 in leap_years:
        return 1
    else:
        return 0

# %%
def year_position(yr):
    leap = leap_checker(yr)
    if yr-1 in leap_years:
        motzaei = 1
        erev = 0
    elif yr+1 in leap_years:
        erev = 1
        motzaei = 0
    else:
        erev = 0
        motzaei = 0
    return motzaei, leap, erev

# %%
#Calculates info for given year

# %%
def tishrei_molad(year):
    machzor=((year-1)//19)+1
    yr_in_machzor = ((year-1)%19)+1
    leap = leap_checker(yr_in_machzor)
    i=1
    q_reg_machzor = 0
    q_leap_machzor = 0
    while i<yr_in_machzor:
        if i in leap_years:
            q_leap_machzor += 1
        else:
            q_reg_machzor += 1
        i+=1
    molsum = [baharad, mult_mol(machzor-1,machzor_remain),mult_mol(q_reg_machzor,yrp_remain),mult_mol(q_leap_machzor,yrm_remain)]
    molad_start = [sum(x) for x in zip(*molsum)]
    molad_start = mol_remainder_remover(molad_start)
    return molad_start,yr_in_machzor

# %%
def next_molad(molad,yr):
    leap = leap_checker(yr)
    new_mol = [x + y for x, y in zip(molad, yr_remain[leap])]
    return new_mol

# %%
def RH_calc(molad,yr):
    RH1 = molad[0]
    yr_rel = year_position(yr)
    #pushes off for Molad Zaken
    if molad[1]>=18:
        RH1 += 1
    
    #pushes off lo ADU
    adu = [1,4,6]
    if RH1 in adu:
        RH1 += 1
    #prevents a 356-day year by delaying a day
    #applies on moatzaei meuberet when molad is on Tues after 9-204
    #dechiya of ג־ט־ר״ד
    elif yr_rel[1] == 0 and molad[0]==3 and (molad[1]>9 or (molad[1]==9 and molad[2]>=204)):
        RH1 = 5
    #prevents a 383 day year in the previous year by pushing later a day
    #applies in leap year when molad is on Mon after 15-589
    #dechiya of בטותקפ״ד
    elif yr_rel[0] == 1 and molad[0]==2 and (molad[1]>15 or (molad[1]==15 and molad[2]>=589)):
        RH1 = 3
        
    RH1 = ((RH1-1)%7)+1
    return RH1

# %%
#display functions
def print_molad(month,molad,leap):
#     print('The Molad of',months1[leap][month],'will be at',molad[0],'days,',molad[1],'hours, and',molad[2],'chalakim')
    print("%",months1[leap][month])
    print(molad[0],"-",molad[1],"-",molad[2])
    
def print_RCh(month,day1,days,leap):
    if days == 2 and day1 == 6:
        print('Rosh Chodesh',months1[leap][month],'will occur on',daynames[day1],'and the following',daynames[(day1+1)%7])
    elif days == 2:
        print('Rosh Chodesh',months1[leap][month],'will occur on',daynames[day1],'and',daynames[day1+1])
    else:
        print('Rosh Chodesh',months1[leap][month],'will occur on',daynames[day1])

# %%
def inc_date(date,inc):
    #only works within a month
    date[1] = date[1] + inc
    date[2] = date[2] + inc
    date[2] = (date[2]-1)%7+1
    return date

# %%
def new_month(month_len,leap,date,last_RCh,molads):
    RCh_len = month_len[leap][date[0]-1]-28
    RCh_day = inc_date(last_RCh,29)[2]
    date = inc_date(last_RCh,month_len[leap][date[0]])
    
    print_RCh(date[0],RCh_day,RCh_len,leap)
    print_molad(date[0],molads[date[0]],leap)

# %%
def daysinyear(year,RH1,RH2):
    if RH1>RH2:
        RH_int = RH2+7-RH1
    else:
        RH_int = RH2-RH1
    #days in year
    leap = leap_checker(year)
    if leap == 0:
        days = 353
    elif leap == 1:
        days = 383
    offset = days%7
    excess = 0
    while offset != RH_int:
        days += 1
        offset = days%7
        excess += 1
    return days,excess

# %%
def gregdate(year,month,day):
    months_hebcal = ['Tishrei', 'Cheshvan', 'Kislev', 'Tevet', 'Shvat', 'Adar1', 'Adar2', 'Nisan', 'Iyyar', 'Sivan', 'Tamuz', 'Av', 'Elul']
    leap = leap_checker(year)
    if leap == 0 and month > 6:
        month_ = months_hebcal[month]
    else:
        month_ = months_hebcal[month-1]
    import urllib.request, json, datetime
    with urllib.request.urlopen("https://www.hebcal.com/converter?cfg=json&hy="+str(year)+"&hm="+str(month_)+"&hd="+str(day)+"&h2g=1") as url:
        data = json.loads(url.read().decode())
        #print(data)
    greg_date = datetime.date(data['gy'],data['gm'],data['gd'])
    print(greg_date)

# %%
def run_year(year):
    year_info = tishrei_molad(year)
    year_molad = year_info[0]
    year_in_machzor = year_info[1]
    RH1 = RH_calc(*year_info)
    next_year_info = tishrei_molad(year+1)
    RH2 = RH_calc(*next_year_info)
    leap = leap_checker(year)
    excess = daysinyear(year,RH1,RH2)[1]
    
    if excess == 0:
        yr_type = '0'
        yr_type2 = 'ח'
    elif excess == 1:
        yr_type = '1'
        yr_type2 = 'כ'
    elif excess == 2:
        yr_type = '2'
        yr_type2 = 'ש'
        
    if excess == 0:
        chesh_len = 29
        kis_len = 29
    elif excess == 1:
        chesh_len = 29
        kis_len = 30
    elif excess == 2:
        chesh_len = 30
        kis_len = 30
    month_lengths_p = [30,chesh_len,kis_len,29,30,29,30,29,30,29,30,29]
    month_lengths_m = [30,chesh_len,kis_len,29,30,30,29,30,29,30,29,30,29]
    month_len = [month_lengths_p,month_lengths_m]
    pesach_day = RH2-2
    if pesach_day < 1:
        pesach_day = pesach_day + 7
    yrcode1 = str(RH1)+yr_type+str(pesach_day)
    yrcode2 = daysorder[RH1-1]+yr_type2+'״'+daysorder[pesach_day-1]
    #print basic calendar info--the year and the year-type
#     if leap==0:
#         leap_print = 'Shana Peshuta (non-leap year)'
#     else:
#         leap_print = 'Shana Meubberet (leap year)'
    
    #calculates molads for the year
    molads = [year_info[0]]
    month = 1
    months = 12+leap
    while month<months:
        molads.append(add_mol(molads[month-1],monthly_molad))
        month += 1
    #print(year,yrcode1,yrcode2,leap_print,'Year',year_in_machzor,'of the 19-year cycle')
    if 
    if year % 10 == 0:
        print(year,"&",yrcode1)
    else:
        print("&",yrcode1)
    #now increment through each month and print relevant info
    #use array for [month,day,day of week]
    date = [1,1,RH1]
    RH_date = date
    last_RCh = RH_date 
   # print(RH_date)
#     print_molad(date[0]-1,year_info[0],leap)
#     print('Rosh HaShana occurs on',daynames[RH1-1],'and',daynames[RH1%7],'\n')
#     #print(RH_date)
#     date = inc_date(date,2)
#     if date[2] == 7:
#         print('Shabbat Shuva is directly after the 2nd day of Rosh HaShana.  Tzom Gedalia is pushed off to Sunday')
#     else:
#         print('Tzom Gedalia is',daynames[date[2]],'\n')
#         #print(RH_date)
#         while date[2]!=7:
#             inc_date(date,1)
#         print('Shabbat Shuva is',date[1],'Tishrei (special haftarah)\n')
    
    
#     #new_month(month_len,leap,date,last_RCh,molads)
#     #issues with RCh date
#     date[0] = date[0]+1
#     date[1] = 1
#     last_RCh = date
    
#     new_month(month_len,leap,date,last_RCh,molads)
    month_molad = []
    month_molad.append(year_molad)
    print("\multirow{2}{*}{"+str(year)+"}")
    print("&",year_molad[0],"-",year_molad[1],"-",year_molad[2])
    month_counter = 1
    for i in range(1,len(months1[leap])):

        new_molad = add_mol(month_molad[i-1],monthly_molad)
        month_molad.append(new_molad)
        print("&")
        print_molad(i,month_molad[i],leap)
        month_counter += 1
        if leap == 0 and month_counter == 6:
            print(r"&\space\\* \space")
        if leap == 1 and month_counter == 7:
            print(r"\\* \space")
    print(r"&\space\\\hline")

# %%
#year = input('Enter a year in the Hebrew calendar ')
#year = int(year)
year = 5784
run_year(year)
# Out:
# \multirow{2}{*}{5784}
# & 6 - 11 - 882
# &
# % Mar\d{h}eshvan
# 1 - 0 - 595
# &
# % Kislev
# 2 - 13 - 308
# &
# % Tevet
# 4 - 2 - 21
# &
# % Shevat
# 5 - 14 - 814
# &
# % Adar I
# 7 - 3 - 527
# &
# % Adar II
# 1 - 16 - 240
# \\* \space
# &
# % Nisan
# 3 - 4 - 1033
# &
# % Iyyar
# 4 - 17 - 746
# &
# % Sivan
# 6 - 6 - 459
# &
# % Tammuz
# 7 - 19 - 172
# &
# % Av
# 2 - 7 - 965
# &
# % Elul
# 3 - 20 - 678
# &\space\\\hline

# %%
year = 5784
while year < 5900:
    run_year(year)
    year += 1
# Out:
# \multirow{2}{*}{5784}
# & 6 - 11 - 882
# &
# % Mar\d{h}eshvan
# 1 - 0 - 595
# &
# % Kislev
# 2 - 13 - 308
# &
# % Tevet
# 4 - 2 - 21
# &
# % Shevat
# 5 - 14 - 814
# &
# % Adar I
# 7 - 3 - 527
# &
# % Adar II
# 1 - 16 - 240
# \\* \space
# &
# % Nisan
# 3 - 4 - 1033
# &
# % Iyyar
# 4 - 17 - 746
# &
# % Sivan
# 6 - 6 - 459
# &
# % Tammuz
# 7 - 19 - 172
# &
# % Av
# 2 - 7 - 965
# &
# % Elul
# 3 - 20 - 678
# &\space\\\hline
# \multirow{2}{*}{5785}
# & 5 - 9 - 391
# &
# % Mar\d{h}eshvan
# 6 - 22 - 104
# &
# % Kislev
# 1 - 10 - 897
# &
# % Tevet
# 2 - 23 - 610
# &
# % Shevat
# 4 - 12 - 323
# &
# % Adar
# 6 - 1 - 36
# &\space\\* \space
# &
# % Nisan
# 7 - 13 - 829
# &
# % Iyyar
# 2 - 2 - 542
# &
# % Sivan
# 3 - 15 - 255
# &
# % Tammuz
# 5 - 3 - 1048
# &
# % Av
# 6 - 16 - 761
# &
# % Elul
# 1 - 5 - 474
# &\space\\\hline
# \multirow{2}{*}{5786}
# & 2 - 18 - 187
# &
# % Mar\d{h}eshvan
# 4 - 6 - 980
# &
# % Kislev
# 5 - 19 - 693
# &
# % Tevet
# 7 - 8 - 406
# &
# % Shevat
# 1 - 21 - 119
# &
# % Adar
# 3 - 9 - 912
# &\space\\* \space
# &
# % Nisan
# 4 - 22 - 625
# &
# % Iyyar
# 6 - 11 - 338
# &
# % Sivan
# 1 - 0 - 51
# &
# % Tammuz
# 2 - 12 - 844
# &
# % Av
# 4 - 1 - 557
# &
# % Elul
# 5 - 14 - 270
# &\space\\\hline
# \multirow{2}{*}{5787}
# & 7 - 2 - 1063
# &
# % Mar\d{h}eshvan
# 1 - 15 - 776
# &
# % Kislev
# 3 - 4 - 489
# &
# % Tevet
# 4 - 17 - 202
# &
# % Shevat
# 6 - 5 - 995
# &
# % Adar I
# 7 - 18 - 708
# &
# % Adar II
# 2 - 7 - 421
# \\* \space
# &
# % Nisan
# 3 - 20 - 134
# &
# % Iyyar
# 5 - 8 - 927
# &
# % Sivan
# 6 - 21 - 640
# &
# % Tammuz
# 1 - 10 - 353
# &
# % Av
# 2 - 23 - 66
# &
# % Elul
# 4 - 11 - 859
# &\space\\\hline
# \multirow{2}{*}{5788}
# & 6 - 0 - 572
# &
# % Mar\d{h}eshvan
# 7 - 13 - 285
# &
# % Kislev
# 2 - 1 - 1078
# &
# % Tevet
# 3 - 14 - 791
# &
# % Shevat
# 5 - 3 - 504
# &
# % Adar
# 6 - 16 - 217
# &\space\\* \space
# &
# % Nisan
# 1 - 4 - 1010
# &
# % Iyyar
# 2 - 17 - 723
# &
# % Sivan
# 4 - 6 - 436
# &
# % Tammuz
# 5 - 19 - 149
# &
# % Av
# 7 - 7 - 942
# &
# % Elul
# 1 - 20 - 655
# &\space\\\hline
# \multirow{2}{*}{5789}
# & 3 - 9 - 368
# &
# % Mar\d{h}eshvan
# 4 - 22 - 81
# &
# % Kislev
# 6 - 10 - 874
# &
# % Tevet
# 7 - 23 - 587
# &
# % Shevat
# 2 - 12 - 300
# &
# % Adar
# 4 - 1 - 13
# &\space\\* \space
# &
# % Nisan
# 5 - 13 - 806
# &
# % Iyyar
# 7 - 2 - 519
# &
# % Sivan
# 1 - 15 - 232
# &
# % Tammuz
# 3 - 3 - 1025
# &
# % Av
# 4 - 16 - 738
# &
# % Elul
# 6 - 5 - 451
# &\space\\\hline
# \multirow{2}{*}{5790}
# & 7 - 18 - 164
# &
# % Mar\d{h}eshvan
# 2 - 6 - 957
# &
# % Kislev
# 3 - 19 - 670
# &
# % Tevet
# 5 - 8 - 383
# &
# % Shevat
# 6 - 21 - 96
# &
# % Adar I
# 1 - 9 - 889
# &
# % Adar II
# 2 - 22 - 602
# \\* \space
# &
# % Nisan
# 4 - 11 - 315
# &
# % Iyyar
# 6 - 0 - 28
# &
# % Sivan
# 7 - 12 - 821
# &
# % Tammuz
# 2 - 1 - 534
# &
# % Av
# 3 - 14 - 247
# &
# % Elul
# 5 - 2 - 1040
# &\space\\\hline
# \multirow{2}{*}{5791}
# & 6 - 15 - 753
# &
# % Mar\d{h}eshvan
# 1 - 4 - 466
# &
# % Kislev
# 2 - 17 - 179
# &
# % Tevet
# 4 - 5 - 972
# &
# % Shevat
# 5 - 18 - 685
# &
# % Adar
# 7 - 7 - 398
# &\space\\* \space
# &
# % Nisan
# 1 - 20 - 111
# &
# % Iyyar
# 3 - 8 - 904
# &
# % Sivan
# 4 - 21 - 617
# &
# % Tammuz
# 6 - 10 - 330
# &
# % Av
# 7 - 23 - 43
# &
# % Elul
# 2 - 11 - 836
# &\space\\\hline
# \multirow{2}{*}{5792}
# & 4 - 0 - 549
# &
# % Mar\d{h}eshvan
# 5 - 13 - 262
# &
# % Kislev
# 7 - 1 - 1055
# &
# % Tevet
# 1 - 14 - 768
# &
# % Shevat
# 3 - 3 - 481
# &
# % Adar
# 4 - 16 - 194
# &\space\\* \space
# &
# % Nisan
# 6 - 4 - 987
# &
# % Iyyar
# 7 - 17 - 700
# &
# % Sivan
# 2 - 6 - 413
# &
# % Tammuz
# 3 - 19 - 126
# &
# % Av
# 5 - 7 - 919
# &
# % Elul
# 6 - 20 - 632
# &\space\\\hline
# \multirow{2}{*}{5793}
# & 1 - 9 - 345
# &
# % Mar\d{h}eshvan
# 2 - 22 - 58
# &
# % Kislev
# 4 - 10 - 851
# &
# % Tevet
# 5 - 23 - 564
# &
# % Shevat
# 7 - 12 - 277
# &
# % Adar I
# 2 - 0 - 1070
# &
# % Adar II
# 3 - 13 - 783
# \\* \space
# &
# % Nisan
# 5 - 2 - 496
# &
# % Iyyar
# 6 - 15 - 209
# &
# % Sivan
# 1 - 3 - 1002
# &
# % Tammuz
# 2 - 16 - 715
# &
# % Av
# 4 - 5 - 428
# &
# % Elul
# 5 - 18 - 141
# &\space\\\hline
# \multirow{2}{*}{5794}
# & 7 - 6 - 934
# &
# % Mar\d{h}eshvan
# 1 - 19 - 647
# &
# % Kislev
# 3 - 8 - 360
# &
# % Tevet
# 4 - 21 - 73
# &
# % Shevat
# 6 - 9 - 866
# &
# % Adar
# 7 - 22 - 579
# &\space\\* \space
# &
# % Nisan
# 2 - 11 - 292
# &
# % Iyyar
# 4 - 0 - 5
# &
# % Sivan
# 5 - 12 - 798
# &
# % Tammuz
# 7 - 1 - 511
# &
# % Av
# 1 - 14 - 224
# &
# % Elul
# 3 - 2 - 1017
# &\space\\\hline
# \multirow{2}{*}{5795}
# & 4 - 15 - 730
# &
# % Mar\d{h}eshvan
# 6 - 4 - 443
# &
# % Kislev
# 7 - 17 - 156
# &
# % Tevet
# 2 - 5 - 949
# &
# % Shevat
# 3 - 18 - 662
# &
# % Adar I
# 5 - 7 - 375
# &
# % Adar II
# 6 - 20 - 88
# \\* \space
# &
# % Nisan
# 1 - 8 - 881
# &
# % Iyyar
# 2 - 21 - 594
# &
# % Sivan
# 4 - 10 - 307
# &
# % Tammuz
# 5 - 23 - 20
# &
# % Av
# 7 - 11 - 813
# &
# % Elul
# 2 - 0 - 526
# &\space\\\hline
# \multirow{2}{*}{5796}
# & 3 - 13 - 239
# &
# % Mar\d{h}eshvan
# 5 - 1 - 1032
# &
# % Kislev
# 6 - 14 - 745
# &
# % Tevet
# 1 - 3 - 458
# &
# % Shevat
# 2 - 16 - 171
# &
# % Adar
# 4 - 4 - 964
# &\space\\* \space
# &
# % Nisan
# 5 - 17 - 677
# &
# % Iyyar
# 7 - 6 - 390
# &
# % Sivan
# 1 - 19 - 103
# &
# % Tammuz
# 3 - 7 - 896
# &
# % Av
# 4 - 20 - 609
# &
# % Elul
# 6 - 9 - 322
# &\space\\\hline
# \multirow{2}{*}{5797}
# & 7 - 22 - 35
# &
# % Mar\d{h}eshvan
# 2 - 10 - 828
# &
# % Kislev
# 3 - 23 - 541
# &
# % Tevet
# 5 - 12 - 254
# &
# % Shevat
# 7 - 0 - 1047
# &
# % Adar
# 1 - 13 - 760
# &\space\\* \space
# &
# % Nisan
# 3 - 2 - 473
# &
# % Iyyar
# 4 - 15 - 186
# &
# % Sivan
# 6 - 3 - 979
# &
# % Tammuz
# 7 - 16 - 692
# &
# % Av
# 2 - 5 - 405
# &
# % Elul
# 3 - 18 - 118
# &\space\\\hline
# \multirow{2}{*}{5798}
# & 5 - 6 - 911
# &
# % Mar\d{h}eshvan
# 6 - 19 - 624
# &
# % Kislev
# 1 - 8 - 337
# &
# % Tevet
# 2 - 21 - 50
# &
# % Shevat
# 4 - 9 - 843
# &
# % Adar I
# 5 - 22 - 556
# &
# % Adar II
# 7 - 11 - 269
# \\* \space
# &
# % Nisan
# 1 - 23 - 1062
# &
# % Iyyar
# 3 - 12 - 775
# &
# % Sivan
# 5 - 1 - 488
# &
# % Tammuz
# 6 - 14 - 201
# &
# % Av
# 1 - 2 - 994
# &
# % Elul
# 2 - 15 - 707
# &\space\\\hline
# \multirow{2}{*}{5799}
# & 4 - 4 - 420
# &
# % Mar\d{h}eshvan
# 5 - 17 - 133
# &
# % Kislev
# 7 - 5 - 926
# &
# % Tevet
# 1 - 18 - 639
# &
# % Shevat
# 3 - 7 - 352
# &
# % Adar
# 4 - 20 - 65
# &\space\\* \space
# &
# % Nisan
# 6 - 8 - 858
# &
# % Iyyar
# 7 - 21 - 571
# &
# % Sivan
# 2 - 10 - 284
# &
# % Tammuz
# 3 - 22 - 1077
# &
# % Av
# 5 - 11 - 790
# &
# % Elul
# 7 - 0 - 503
# &\space\\\hline
# \multirow{2}{*}{5800}
# & 1 - 13 - 216
# &
# % Mar\d{h}eshvan
# 3 - 1 - 1009
# &
# % Kislev
# 4 - 14 - 722
# &
# % Tevet
# 6 - 3 - 435
# &
# % Shevat
# 7 - 16 - 148
# &
# % Adar
# 2 - 4 - 941
# &\space\\* \space
# &
# % Nisan
# 3 - 17 - 654
# &
# % Iyyar
# 5 - 6 - 367
# &
# % Sivan
# 6 - 19 - 80
# &
# % Tammuz
# 1 - 7 - 873
# &
# % Av
# 2 - 20 - 586
# &
# % Elul
# 4 - 9 - 299
# &\space\\\hline
# \multirow{2}{*}{5801}
# & 5 - 22 - 12
# &
# % Mar\d{h}eshvan
# 7 - 10 - 805
# &
# % Kislev
# 1 - 23 - 518
# &
# % Tevet
# 3 - 12 - 231
# &
# % Shevat
# 5 - 0 - 1024
# &
# % Adar I
# 6 - 13 - 737
# &
# % Adar II
# 1 - 2 - 450
# \\* \space
# &
# % Nisan
# 2 - 15 - 163
# &
# % Iyyar
# 4 - 3 - 956
# &
# % Sivan
# 5 - 16 - 669
# &
# % Tammuz
# 7 - 5 - 382
# &
# % Av
# 1 - 18 - 95
# &
# % Elul
# 3 - 6 - 888
# &\space\\\hline
# \multirow{2}{*}{5802}
# & 4 - 19 - 601
# &
# % Mar\d{h}eshvan
# 6 - 8 - 314
# &
# % Kislev
# 7 - 21 - 27
# &
# % Tevet
# 2 - 9 - 820
# &
# % Shevat
# 3 - 22 - 533
# &
# % Adar
# 5 - 11 - 246
# &\space\\* \space
# &
# % Nisan
# 6 - 23 - 1039
# &
# % Iyyar
# 1 - 12 - 752
# &
# % Sivan
# 3 - 1 - 465
# &
# % Tammuz
# 4 - 14 - 178
# &
# % Av
# 6 - 2 - 971
# &
# % Elul
# 7 - 15 - 684
# &\space\\\hline
# \multirow{2}{*}{5803}
# & 2 - 4 - 397
# &
# % Mar\d{h}eshvan
# 3 - 17 - 110
# &
# % Kislev
# 5 - 5 - 903
# &
# % Tevet
# 6 - 18 - 616
# &
# % Shevat
# 1 - 7 - 329
# &
# % Adar I
# 2 - 20 - 42
# &
# % Adar II
# 4 - 8 - 835
# \\* \space
# &
# % Nisan
# 5 - 21 - 548
# &
# % Iyyar
# 7 - 10 - 261
# &
# % Sivan
# 1 - 22 - 1054
# &
# % Tammuz
# 3 - 11 - 767
# &
# % Av
# 5 - 0 - 480
# &
# % Elul
# 6 - 13 - 193
# &\space\\\hline
# \multirow{2}{*}{5804}
# & 1 - 1 - 986
# &
# % Mar\d{h}eshvan
# 2 - 14 - 699
# &
# % Kislev
# 4 - 3 - 412
# &
# % Tevet
# 5 - 16 - 125
# &
# % Shevat
# 7 - 4 - 918
# &
# % Adar
# 1 - 17 - 631
# &\space\\* \space
# &
# % Nisan
# 3 - 6 - 344
# &
# % Iyyar
# 4 - 19 - 57
# &
# % Sivan
# 6 - 7 - 850
# &
# % Tammuz
# 7 - 20 - 563
# &
# % Av
# 2 - 9 - 276
# &
# % Elul
# 3 - 21 - 1069
# &\space\\\hline
# \multirow{2}{*}{5805}
# & 5 - 10 - 782
# &
# % Mar\d{h}eshvan
# 6 - 23 - 495
# &
# % Kislev
# 1 - 12 - 208
# &
# % Tevet
# 3 - 0 - 1001
# &
# % Shevat
# 4 - 13 - 714
# &
# % Adar
# 6 - 2 - 427
# &\space\\* \space
# &
# % Nisan
# 7 - 15 - 140
# &
# % Iyyar
# 2 - 3 - 933
# &
# % Sivan
# 3 - 16 - 646
# &
# % Tammuz
# 5 - 5 - 359
# &
# % Av
# 6 - 18 - 72
# &
# % Elul
# 1 - 6 - 865
# &\space\\\hline
# \multirow{2}{*}{5806}
# & 2 - 19 - 578
# &
# % Mar\d{h}eshvan
# 4 - 8 - 291
# &
# % Kislev
# 5 - 21 - 4
# &
# % Tevet
# 7 - 9 - 797
# &
# % Shevat
# 1 - 22 - 510
# &
# % Adar I
# 3 - 11 - 223
# &
# % Adar II
# 4 - 23 - 1016
# \\* \space
# &
# % Nisan
# 6 - 12 - 729
# &
# % Iyyar
# 1 - 1 - 442
# &
# % Sivan
# 2 - 14 - 155
# &
# % Tammuz
# 4 - 2 - 948
# &
# % Av
# 5 - 15 - 661
# &
# % Elul
# 7 - 4 - 374
# &\space\\\hline
# \multirow{2}{*}{5807}
# & 1 - 17 - 87
# &
# % Mar\d{h}eshvan
# 3 - 5 - 880
# &
# % Kislev
# 4 - 18 - 593
# &
# % Tevet
# 6 - 7 - 306
# &
# % Shevat
# 7 - 20 - 19
# &
# % Adar
# 2 - 8 - 812
# &\space\\* \space
# &
# % Nisan
# 3 - 21 - 525
# &
# % Iyyar
# 5 - 10 - 238
# &
# % Sivan
# 6 - 22 - 1031
# &
# % Tammuz
# 1 - 11 - 744
# &
# % Av
# 3 - 0 - 457
# &
# % Elul
# 4 - 13 - 170
# &\space\\\hline
# \multirow{2}{*}{5808}
# & 6 - 1 - 963
# &
# % Mar\d{h}eshvan
# 7 - 14 - 676
# &
# % Kislev
# 2 - 3 - 389
# &
# % Tevet
# 3 - 16 - 102
# &
# % Shevat
# 5 - 4 - 895
# &
# % Adar
# 6 - 17 - 608
# &\space\\* \space
# &
# % Nisan
# 1 - 6 - 321
# &
# % Iyyar
# 2 - 19 - 34
# &
# % Sivan
# 4 - 7 - 827
# &
# % Tammuz
# 5 - 20 - 540
# &
# % Av
# 7 - 9 - 253
# &
# % Elul
# 1 - 21 - 1046
# &\space\\\hline
# \multirow{2}{*}{5809}
# & 3 - 10 - 759
# &
# % Mar\d{h}eshvan
# 4 - 23 - 472
# &
# % Kislev
# 6 - 12 - 185
# &
# % Tevet
# 1 - 0 - 978
# &
# % Shevat
# 2 - 13 - 691
# &
# % Adar I
# 4 - 2 - 404
# &
# % Adar II
# 5 - 15 - 117
# \\* \space
# &
# % Nisan
# 7 - 3 - 910
# &
# % Iyyar
# 1 - 16 - 623
# &
# % Sivan
# 3 - 5 - 336
# &
# % Tammuz
# 4 - 18 - 49
# &
# % Av
# 6 - 6 - 842
# &
# % Elul
# 7 - 19 - 555
# &\space\\\hline
# \multirow{2}{*}{5810}
# & 2 - 8 - 268
# &
# % Mar\d{h}eshvan
# 3 - 20 - 1061
# &
# % Kislev
# 5 - 9 - 774
# &
# % Tevet
# 6 - 22 - 487
# &
# % Shevat
# 1 - 11 - 200
# &
# % Adar
# 2 - 23 - 993
# &\space\\* \space
# &
# % Nisan
# 4 - 12 - 706
# &
# % Iyyar
# 6 - 1 - 419
# &
# % Sivan
# 7 - 14 - 132
# &
# % Tammuz
# 2 - 2 - 925
# &
# % Av
# 3 - 15 - 638
# &
# % Elul
# 5 - 4 - 351
# &\space\\\hline
# \multirow{2}{*}{5811}
# & 6 - 17 - 64
# &
# % Mar\d{h}eshvan
# 1 - 5 - 857
# &
# % Kislev
# 2 - 18 - 570
# &
# % Tevet
# 4 - 7 - 283
# &
# % Shevat
# 5 - 19 - 1076
# &
# % Adar
# 7 - 8 - 789
# &\space\\* \space
# &
# % Nisan
# 1 - 21 - 502
# &
# % Iyyar
# 3 - 10 - 215
# &
# % Sivan
# 4 - 22 - 1008
# &
# % Tammuz
# 6 - 11 - 721
# &
# % Av
# 1 - 0 - 434
# &
# % Elul
# 2 - 13 - 147
# &\space\\\hline
# \multirow{2}{*}{5812}
# & 4 - 1 - 940
# &
# % Mar\d{h}eshvan
# 5 - 14 - 653
# &
# % Kislev
# 7 - 3 - 366
# &
# % Tevet
# 1 - 16 - 79
# &
# % Shevat
# 3 - 4 - 872
# &
# % Adar I
# 4 - 17 - 585
# &
# % Adar II
# 6 - 6 - 298
# \\* \space
# &
# % Nisan
# 7 - 19 - 11
# &
# % Iyyar
# 2 - 7 - 804
# &
# % Sivan
# 3 - 20 - 517
# &
# % Tammuz
# 5 - 9 - 230
# &
# % Av
# 6 - 21 - 1023
# &
# % Elul
# 1 - 10 - 736
# &\space\\\hline
# \multirow{2}{*}{5813}
# & 2 - 23 - 449
# &
# % Mar\d{h}eshvan
# 4 - 12 - 162
# &
# % Kislev
# 6 - 0 - 955
# &
# % Tevet
# 7 - 13 - 668
# &
# % Shevat
# 2 - 2 - 381
# &
# % Adar
# 3 - 15 - 94
# &\space\\* \space
# &
# % Nisan
# 5 - 3 - 887
# &
# % Iyyar
# 6 - 16 - 600
# &
# % Sivan
# 1 - 5 - 313
# &
# % Tammuz
# 2 - 18 - 26
# &
# % Av
# 4 - 6 - 819
# &
# % Elul
# 5 - 19 - 532
# &\space\\\hline
# \multirow{2}{*}{5814}
# & 7 - 8 - 245
# &
# % Mar\d{h}eshvan
# 1 - 20 - 1038
# &
# % Kislev
# 3 - 9 - 751
# &
# % Tevet
# 4 - 22 - 464
# &
# % Shevat
# 6 - 11 - 177
# &
# % Adar I
# 7 - 23 - 970
# &
# % Adar II
# 2 - 12 - 683
# \\* \space
# &
# % Nisan
# 4 - 1 - 396
# &
# % Iyyar
# 5 - 14 - 109
# &
# % Sivan
# 7 - 2 - 902
# &
# % Tammuz
# 1 - 15 - 615
# &
# % Av
# 3 - 4 - 328
# &
# % Elul
# 4 - 17 - 41
# &\space\\\hline
# \multirow{2}{*}{5815}
# & 6 - 5 - 834
# &
# % Mar\d{h}eshvan
# 7 - 18 - 547
# &
# % Kislev
# 2 - 7 - 260
# &
# % Tevet
# 3 - 19 - 1053
# &
# % Shevat
# 5 - 8 - 766
# &
# % Adar
# 6 - 21 - 479
# &\space\\* \space
# &
# % Nisan
# 1 - 10 - 192
# &
# % Iyyar
# 2 - 22 - 985
# &
# % Sivan
# 4 - 11 - 698
# &
# % Tammuz
# 6 - 0 - 411
# &
# % Av
# 7 - 13 - 124
# &
# % Elul
# 2 - 1 - 917
# &\space\\\hline
# \multirow{2}{*}{5816}
# & 3 - 14 - 630
# &
# % Mar\d{h}eshvan
# 5 - 3 - 343
# &
# % Kislev
# 6 - 16 - 56
# &
# % Tevet
# 1 - 4 - 849
# &
# % Shevat
# 2 - 17 - 562
# &
# % Adar
# 4 - 6 - 275
# &\space\\* \space
# &
# % Nisan
# 5 - 18 - 1068
# &
# % Iyyar
# 7 - 7 - 781
# &
# % Sivan
# 1 - 20 - 494
# &
# % Tammuz
# 3 - 9 - 207
# &
# % Av
# 4 - 21 - 1000
# &
# % Elul
# 6 - 10 - 713
# &\space\\\hline
# \multirow{2}{*}{5817}
# & 7 - 23 - 426
# &
# % Mar\d{h}eshvan
# 2 - 12 - 139
# &
# % Kislev
# 4 - 0 - 932
# &
# % Tevet
# 5 - 13 - 645
# &
# % Shevat
# 7 - 2 - 358
# &
# % Adar I
# 1 - 15 - 71
# &
# % Adar II
# 3 - 3 - 864
# \\* \space
# &
# % Nisan
# 4 - 16 - 577
# &
# % Iyyar
# 6 - 5 - 290
# &
# % Sivan
# 7 - 18 - 3
# &
# % Tammuz
# 2 - 6 - 796
# &
# % Av
# 3 - 19 - 509
# &
# % Elul
# 5 - 8 - 222
# &\space\\\hline
# \multirow{2}{*}{5818}
# & 6 - 20 - 1015
# &
# % Mar\d{h}eshvan
# 1 - 9 - 728
# &
# % Kislev
# 2 - 22 - 441
# &
# % Tevet
# 4 - 11 - 154
# &
# % Shevat
# 5 - 23 - 947
# &
# % Adar
# 7 - 12 - 660
# &\space\\* \space
# &
# % Nisan
# 2 - 1 - 373
# &
# % Iyyar
# 3 - 14 - 86
# &
# % Sivan
# 5 - 2 - 879
# &
# % Tammuz
# 6 - 15 - 592
# &
# % Av
# 1 - 4 - 305
# &
# % Elul
# 2 - 17 - 18
# &\space\\\hline
# \multirow{2}{*}{5819}
# & 4 - 5 - 811
# &
# % Mar\d{h}eshvan
# 5 - 18 - 524
# &
# % Kislev
# 7 - 7 - 237
# &
# % Tevet
# 1 - 19 - 1030
# &
# % Shevat
# 3 - 8 - 743
# &
# % Adar
# 4 - 21 - 456
# &\space\\* \space
# &
# % Nisan
# 6 - 10 - 169
# &
# % Iyyar
# 7 - 22 - 962
# &
# % Sivan
# 2 - 11 - 675
# &
# % Tammuz
# 4 - 0 - 388
# &
# % Av
# 5 - 13 - 101
# &
# % Elul
# 7 - 1 - 894
# &\space\\\hline
# \multirow{2}{*}{5820}
# & 1 - 14 - 607
# &
# % Mar\d{h}eshvan
# 3 - 3 - 320
# &
# % Kislev
# 4 - 16 - 33
# &
# % Tevet
# 6 - 4 - 826
# &
# % Shevat
# 7 - 17 - 539
# &
# % Adar I
# 2 - 6 - 252
# &
# % Adar II
# 3 - 18 - 1045
# \\* \space
# &
# % Nisan
# 5 - 7 - 758
# &
# % Iyyar
# 6 - 20 - 471
# &
# % Sivan
# 1 - 9 - 184
# &
# % Tammuz
# 2 - 21 - 977
# &
# % Av
# 4 - 10 - 690
# &
# % Elul
# 5 - 23 - 403
# &\space\\\hline
# \multirow{2}{*}{5821}
# & 7 - 12 - 116
# &
# % Mar\d{h}eshvan
# 2 - 0 - 909
# &
# % Kislev
# 3 - 13 - 622
# &
# % Tevet
# 5 - 2 - 335
# &
# % Shevat
# 6 - 15 - 48
# &
# % Adar
# 1 - 3 - 841
# &\space\\* \space
# &
# % Nisan
# 2 - 16 - 554
# &
# % Iyyar
# 4 - 5 - 267
# &
# % Sivan
# 5 - 17 - 1060
# &
# % Tammuz
# 7 - 6 - 773
# &
# % Av
# 1 - 19 - 486
# &
# % Elul
# 3 - 8 - 199
# &\space\\\hline
# \multirow{2}{*}{5822}
# & 4 - 20 - 992
# &
# % Mar\d{h}eshvan
# 6 - 9 - 705
# &
# % Kislev
# 7 - 22 - 418
# &
# % Tevet
# 2 - 11 - 131
# &
# % Shevat
# 3 - 23 - 924
# &
# % Adar I
# 5 - 12 - 637
# &
# % Adar II
# 7 - 1 - 350
# \\* \space
# &
# % Nisan
# 1 - 14 - 63
# &
# % Iyyar
# 3 - 2 - 856
# &
# % Sivan
# 4 - 15 - 569
# &
# % Tammuz
# 6 - 4 - 282
# &
# % Av
# 7 - 16 - 1075
# &
# % Elul
# 2 - 5 - 788
# &\space\\\hline
# \multirow{2}{*}{5823}
# & 3 - 18 - 501
# &
# % Mar\d{h}eshvan
# 5 - 7 - 214
# &
# % Kislev
# 6 - 19 - 1007
# &
# % Tevet
# 1 - 8 - 720
# &
# % Shevat
# 2 - 21 - 433
# &
# % Adar
# 4 - 10 - 146
# &\space\\* \space
# &
# % Nisan
# 5 - 22 - 939
# &
# % Iyyar
# 7 - 11 - 652
# &
# % Sivan
# 2 - 0 - 365
# &
# % Tammuz
# 3 - 13 - 78
# &
# % Av
# 5 - 1 - 871
# &
# % Elul
# 6 - 14 - 584
# &\space\\\hline
# \multirow{2}{*}{5824}
# & 1 - 3 - 297
# &
# % Mar\d{h}eshvan
# 2 - 16 - 10
# &
# % Kislev
# 4 - 4 - 803
# &
# % Tevet
# 5 - 17 - 516
# &
# % Shevat
# 7 - 6 - 229
# &
# % Adar
# 1 - 18 - 1022
# &\space\\* \space
# &
# % Nisan
# 3 - 7 - 735
# &
# % Iyyar
# 4 - 20 - 448
# &
# % Sivan
# 6 - 9 - 161
# &
# % Tammuz
# 7 - 21 - 954
# &
# % Av
# 2 - 10 - 667
# &
# % Elul
# 3 - 23 - 380
# &\space\\\hline
# \multirow{2}{*}{5825}
# & 5 - 12 - 93
# &
# % Mar\d{h}eshvan
# 7 - 0 - 886
# &
# % Kislev
# 1 - 13 - 599
# &
# % Tevet
# 3 - 2 - 312
# &
# % Shevat
# 4 - 15 - 25
# &
# % Adar I
# 6 - 3 - 818
# &
# % Adar II
# 7 - 16 - 531
# \\* \space
# &
# % Nisan
# 2 - 5 - 244
# &
# % Iyyar
# 3 - 17 - 1037
# &
# % Sivan
# 5 - 6 - 750
# &
# % Tammuz
# 6 - 19 - 463
# &
# % Av
# 1 - 8 - 176
# &
# % Elul
# 2 - 20 - 969
# &\space\\\hline
# \multirow{2}{*}{5826}
# & 4 - 9 - 682
# &
# % Mar\d{h}eshvan
# 5 - 22 - 395
# &
# % Kislev
# 7 - 11 - 108
# &
# % Tevet
# 1 - 23 - 901
# &
# % Shevat
# 3 - 12 - 614
# &
# % Adar
# 5 - 1 - 327
# &\space\\* \space
# &
# % Nisan
# 6 - 14 - 40
# &
# % Iyyar
# 1 - 2 - 833
# &
# % Sivan
# 2 - 15 - 546
# &
# % Tammuz
# 4 - 4 - 259
# &
# % Av
# 5 - 16 - 1052
# &
# % Elul
# 7 - 5 - 765
# &\space\\\hline
# \multirow{2}{*}{5827}
# & 1 - 18 - 478
# &
# % Mar\d{h}eshvan
# 3 - 7 - 191
# &
# % Kislev
# 4 - 19 - 984
# &
# % Tevet
# 6 - 8 - 697
# &
# % Shevat
# 7 - 21 - 410
# &
# % Adar
# 2 - 10 - 123
# &\space\\* \space
# &
# % Nisan
# 3 - 22 - 916
# &
# % Iyyar
# 5 - 11 - 629
# &
# % Sivan
# 7 - 0 - 342
# &
# % Tammuz
# 1 - 13 - 55
# &
# % Av
# 3 - 1 - 848
# &
# % Elul
# 4 - 14 - 561
# &\space\\\hline
# \multirow{2}{*}{5828}
# & 6 - 3 - 274
# &
# % Mar\d{h}eshvan
# 7 - 15 - 1067
# &
# % Kislev
# 2 - 4 - 780
# &
# % Tevet
# 3 - 17 - 493
# &
# % Shevat
# 5 - 6 - 206
# &
# % Adar I
# 6 - 18 - 999
# &
# % Adar II
# 1 - 7 - 712
# \\* \space
# &
# % Nisan
# 2 - 20 - 425
# &
# % Iyyar
# 4 - 9 - 138
# &
# % Sivan
# 5 - 21 - 931
# &
# % Tammuz
# 7 - 10 - 644
# &
# % Av
# 1 - 23 - 357
# &
# % Elul
# 3 - 12 - 70
# &\space\\\hline
# \multirow{2}{*}{5829}
# & 5 - 0 - 863
# &
# % Mar\d{h}eshvan
# 6 - 13 - 576
# &
# % Kislev
# 1 - 2 - 289
# &
# % Tevet
# 2 - 15 - 2
# &
# % Shevat
# 4 - 3 - 795
# &
# % Adar
# 5 - 16 - 508
# &\space\\* \space
# &
# % Nisan
# 7 - 5 - 221
# &
# % Iyyar
# 1 - 17 - 1014
# &
# % Sivan
# 3 - 6 - 727
# &
# % Tammuz
# 4 - 19 - 440
# &
# % Av
# 6 - 8 - 153
# &
# % Elul
# 7 - 20 - 946
# &\space\\\hline
# \multirow{2}{*}{5830}
# & 2 - 9 - 659
# &
# % Mar\d{h}eshvan
# 3 - 22 - 372
# &
# % Kislev
# 5 - 11 - 85
# &
# % Tevet
# 6 - 23 - 878
# &
# % Shevat
# 1 - 12 - 591
# &
# % Adar
# 3 - 1 - 304
# &\space\\* \space
# &
# % Nisan
# 4 - 14 - 17
# &
# % Iyyar
# 6 - 2 - 810
# &
# % Sivan
# 7 - 15 - 523
# &
# % Tammuz
# 2 - 4 - 236
# &
# % Av
# 3 - 16 - 1029
# &
# % Elul
# 5 - 5 - 742
# &\space\\\hline
# \multirow{2}{*}{5831}
# & 6 - 18 - 455
# &
# % Mar\d{h}eshvan
# 1 - 7 - 168
# &
# % Kislev
# 2 - 19 - 961
# &
# % Tevet
# 4 - 8 - 674
# &
# % Shevat
# 5 - 21 - 387
# &
# % Adar I
# 7 - 10 - 100
# &
# % Adar II
# 1 - 22 - 893
# \\* \space
# &
# % Nisan
# 3 - 11 - 606
# &
# % Iyyar
# 5 - 0 - 319
# &
# % Sivan
# 6 - 13 - 32
# &
# % Tammuz
# 1 - 1 - 825
# &
# % Av
# 2 - 14 - 538
# &
# % Elul
# 4 - 3 - 251
# &\space\\\hline
# \multirow{2}{*}{5832}
# & 5 - 15 - 1044
# &
# % Mar\d{h}eshvan
# 7 - 4 - 757
# &
# % Kislev
# 1 - 17 - 470
# &
# % Tevet
# 3 - 6 - 183
# &
# % Shevat
# 4 - 18 - 976
# &
# % Adar
# 6 - 7 - 689
# &\space\\* \space
# &
# % Nisan
# 7 - 20 - 402
# &
# % Iyyar
# 2 - 9 - 115
# &
# % Sivan
# 3 - 21 - 908
# &
# % Tammuz
# 5 - 10 - 621
# &
# % Av
# 6 - 23 - 334
# &
# % Elul
# 1 - 12 - 47
# &\space\\\hline
# \multirow{2}{*}{5833}
# & 3 - 0 - 840
# &
# % Mar\d{h}eshvan
# 4 - 13 - 553
# &
# % Kislev
# 6 - 2 - 266
# &
# % Tevet
# 7 - 14 - 1059
# &
# % Shevat
# 2 - 3 - 772
# &
# % Adar I
# 3 - 16 - 485
# &
# % Adar II
# 5 - 5 - 198
# \\* \space
# &
# % Nisan
# 6 - 17 - 991
# &
# % Iyyar
# 1 - 6 - 704
# &
# % Sivan
# 2 - 19 - 417
# &
# % Tammuz
# 4 - 8 - 130
# &
# % Av
# 5 - 20 - 923
# &
# % Elul
# 7 - 9 - 636
# &\space\\\hline
# \multirow{2}{*}{5834}
# & 1 - 22 - 349
# &
# % Mar\d{h}eshvan
# 3 - 11 - 62
# &
# % Kislev
# 4 - 23 - 855
# &
# % Tevet
# 6 - 12 - 568
# &
# % Shevat
# 1 - 1 - 281
# &
# % Adar
# 2 - 13 - 1074
# &\space\\* \space
# &
# % Nisan
# 4 - 2 - 787
# &
# % Iyyar
# 5 - 15 - 500
# &
# % Sivan
# 7 - 4 - 213
# &
# % Tammuz
# 1 - 16 - 1006
# &
# % Av
# 3 - 5 - 719
# &
# % Elul
# 4 - 18 - 432
# &\space\\\hline
# \multirow{2}{*}{5835}
# & 6 - 7 - 145
# &
# % Mar\d{h}eshvan
# 7 - 19 - 938
# &
# % Kislev
# 2 - 8 - 651
# &
# % Tevet
# 3 - 21 - 364
# &
# % Shevat
# 5 - 10 - 77
# &
# % Adar
# 6 - 22 - 870
# &\space\\* \space
# &
# % Nisan
# 1 - 11 - 583
# &
# % Iyyar
# 3 - 0 - 296
# &
# % Sivan
# 4 - 13 - 9
# &
# % Tammuz
# 6 - 1 - 802
# &
# % Av
# 7 - 14 - 515
# &
# % Elul
# 2 - 3 - 228
# &\space\\\hline
# \multirow{2}{*}{5836}
# & 3 - 15 - 1021
# &
# % Mar\d{h}eshvan
# 5 - 4 - 734
# &
# % Kislev
# 6 - 17 - 447
# &
# % Tevet
# 1 - 6 - 160
# &
# % Shevat
# 2 - 18 - 953
# &
# % Adar I
# 4 - 7 - 666
# &
# % Adar II
# 5 - 20 - 379
# \\* \space
# &
# % Nisan
# 7 - 9 - 92
# &
# % Iyyar
# 1 - 21 - 885
# &
# % Sivan
# 3 - 10 - 598
# &
# % Tammuz
# 4 - 23 - 311
# &
# % Av
# 6 - 12 - 24
# &
# % Elul
# 1 - 0 - 817
# &\space\\\hline
# \multirow{2}{*}{5837}
# & 2 - 13 - 530
# &
# % Mar\d{h}eshvan
# 4 - 2 - 243
# &
# % Kislev
# 5 - 14 - 1036
# &
# % Tevet
# 7 - 3 - 749
# &
# % Shevat
# 1 - 16 - 462
# &
# % Adar
# 3 - 5 - 175
# &\space\\* \space
# &
# % Nisan
# 4 - 17 - 968
# &
# % Iyyar
# 6 - 6 - 681
# &
# % Sivan
# 7 - 19 - 394
# &
# % Tammuz
# 2 - 8 - 107
# &
# % Av
# 3 - 20 - 900
# &
# % Elul
# 5 - 9 - 613
# &\space\\\hline
# \multirow{2}{*}{5838}
# & 6 - 22 - 326
# &
# % Mar\d{h}eshvan
# 1 - 11 - 39
# &
# % Kislev
# 2 - 23 - 832
# &
# % Tevet
# 4 - 12 - 545
# &
# % Shevat
# 6 - 1 - 258
# &
# % Adar
# 7 - 13 - 1051
# &\space\\* \space
# &
# % Nisan
# 2 - 2 - 764
# &
# % Iyyar
# 3 - 15 - 477
# &
# % Sivan
# 5 - 4 - 190
# &
# % Tammuz
# 6 - 16 - 983
# &
# % Av
# 1 - 5 - 696
# &
# % Elul
# 2 - 18 - 409
# &\space\\\hline
# \multirow{2}{*}{5839}
# & 4 - 7 - 122
# &
# % Mar\d{h}eshvan
# 5 - 19 - 915
# &
# % Kislev
# 7 - 8 - 628
# &
# % Tevet
# 1 - 21 - 341
# &
# % Shevat
# 3 - 10 - 54
# &
# % Adar I
# 4 - 22 - 847
# &
# % Adar II
# 6 - 11 - 560
# \\* \space
# &
# % Nisan
# 1 - 0 - 273
# &
# % Iyyar
# 2 - 12 - 1066
# &
# % Sivan
# 4 - 1 - 779
# &
# % Tammuz
# 5 - 14 - 492
# &
# % Av
# 7 - 3 - 205
# &
# % Elul
# 1 - 15 - 998
# &\space\\\hline
# \multirow{2}{*}{5840}
# & 3 - 4 - 711
# &
# % Mar\d{h}eshvan
# 4 - 17 - 424
# &
# % Kislev
# 6 - 6 - 137
# &
# % Tevet
# 7 - 18 - 930
# &
# % Shevat
# 2 - 7 - 643
# &
# % Adar
# 3 - 20 - 356
# &\space\\* \space
# &
# % Nisan
# 5 - 9 - 69
# &
# % Iyyar
# 6 - 21 - 862
# &
# % Sivan
# 1 - 10 - 575
# &
# % Tammuz
# 2 - 23 - 288
# &
# % Av
# 4 - 12 - 1
# &
# % Elul
# 6 - 0 - 794
# &\space\\\hline
# \multirow{2}{*}{5841}
# & 7 - 13 - 507
# &
# % Mar\d{h}eshvan
# 2 - 2 - 220
# &
# % Kislev
# 3 - 14 - 1013
# &
# % Tevet
# 5 - 3 - 726
# &
# % Shevat
# 6 - 16 - 439
# &
# % Adar I
# 1 - 5 - 152
# &
# % Adar II
# 2 - 17 - 945
# \\* \space
# &
# % Nisan
# 4 - 6 - 658
# &
# % Iyyar
# 5 - 19 - 371
# &
# % Sivan
# 7 - 8 - 84
# &
# % Tammuz
# 1 - 20 - 877
# &
# % Av
# 3 - 9 - 590
# &
# % Elul
# 4 - 22 - 303
# &\space\\\hline
# \multirow{2}{*}{5842}
# & 6 - 11 - 16
# &
# % Mar\d{h}eshvan
# 7 - 23 - 809
# &
# % Kislev
# 2 - 12 - 522
# &
# % Tevet
# 4 - 1 - 235
# &
# % Shevat
# 5 - 13 - 1028
# &
# % Adar
# 7 - 2 - 741
# &\space\\* \space
# &
# % Nisan
# 1 - 15 - 454
# &
# % Iyyar
# 3 - 4 - 167
# &
# % Sivan
# 4 - 16 - 960
# &
# % Tammuz
# 6 - 5 - 673
# &
# % Av
# 7 - 18 - 386
# &
# % Elul
# 2 - 7 - 99
# &\space\\\hline
# \multirow{2}{*}{5843}
# & 3 - 19 - 892
# &
# % Mar\d{h}eshvan
# 5 - 8 - 605
# &
# % Kislev
# 6 - 21 - 318
# &
# % Tevet
# 1 - 10 - 31
# &
# % Shevat
# 2 - 22 - 824
# &
# % Adar
# 4 - 11 - 537
# &\space\\* \space
# &
# % Nisan
# 6 - 0 - 250
# &
# % Iyyar
# 7 - 12 - 1043
# &
# % Sivan
# 2 - 1 - 756
# &
# % Tammuz
# 3 - 14 - 469
# &
# % Av
# 5 - 3 - 182
# &
# % Elul
# 6 - 15 - 975
# &\space\\\hline
# \multirow{2}{*}{5844}
# & 1 - 4 - 688
# &
# % Mar\d{h}eshvan
# 2 - 17 - 401
# &
# % Kislev
# 4 - 6 - 114
# &
# % Tevet
# 5 - 18 - 907
# &
# % Shevat
# 7 - 7 - 620
# &
# % Adar I
# 1 - 20 - 333
# &
# % Adar II
# 3 - 9 - 46
# \\* \space
# &
# % Nisan
# 4 - 21 - 839
# &
# % Iyyar
# 6 - 10 - 552
# &
# % Sivan
# 7 - 23 - 265
# &
# % Tammuz
# 2 - 11 - 1058
# &
# % Av
# 4 - 0 - 771
# &
# % Elul
# 5 - 13 - 484
# &\space\\\hline
# \multirow{2}{*}{5845}
# & 7 - 2 - 197
# &
# % Mar\d{h}eshvan
# 1 - 14 - 990
# &
# % Kislev
# 3 - 3 - 703
# &
# % Tevet
# 4 - 16 - 416
# &
# % Shevat
# 6 - 5 - 129
# &
# % Adar
# 7 - 17 - 922
# &\space\\* \space
# &
# % Nisan
# 2 - 6 - 635
# &
# % Iyyar
# 3 - 19 - 348
# &
# % Sivan
# 5 - 8 - 61
# &
# % Tammuz
# 6 - 20 - 854
# &
# % Av
# 1 - 9 - 567
# &
# % Elul
# 2 - 22 - 280
# &\space\\\hline
# \multirow{2}{*}{5846}
# & 4 - 10 - 1073
# &
# % Mar\d{h}eshvan
# 5 - 23 - 786
# &
# % Kislev
# 7 - 12 - 499
# &
# % Tevet
# 2 - 1 - 212
# &
# % Shevat
# 3 - 13 - 1005
# &
# % Adar
# 5 - 2 - 718
# &\space\\* \space
# &
# % Nisan
# 6 - 15 - 431
# &
# % Iyyar
# 1 - 4 - 144
# &
# % Sivan
# 2 - 16 - 937
# &
# % Tammuz
# 4 - 5 - 650
# &
# % Av
# 5 - 18 - 363
# &
# % Elul
# 7 - 7 - 76
# &\space\\\hline
# \multirow{2}{*}{5847}
# & 1 - 19 - 869
# &
# % Mar\d{h}eshvan
# 3 - 8 - 582
# &
# % Kislev
# 4 - 21 - 295
# &
# % Tevet
# 6 - 10 - 8
# &
# % Shevat
# 7 - 22 - 801
# &
# % Adar I
# 2 - 11 - 514
# &
# % Adar II
# 4 - 0 - 227
# \\* \space
# &
# % Nisan
# 5 - 12 - 1020
# &
# % Iyyar
# 7 - 1 - 733
# &
# % Sivan
# 1 - 14 - 446
# &
# % Tammuz
# 3 - 3 - 159
# &
# % Av
# 4 - 15 - 952
# &
# % Elul
# 6 - 4 - 665
# &\space\\\hline
# \multirow{2}{*}{5848}
# & 7 - 17 - 378
# &
# % Mar\d{h}eshvan
# 2 - 6 - 91
# &
# % Kislev
# 3 - 18 - 884
# &
# % Tevet
# 5 - 7 - 597
# &
# % Shevat
# 6 - 20 - 310
# &
# % Adar
# 1 - 9 - 23
# &\space\\* \space
# &
# % Nisan
# 2 - 21 - 816
# &
# % Iyyar
# 4 - 10 - 529
# &
# % Sivan
# 5 - 23 - 242
# &
# % Tammuz
# 7 - 11 - 1035
# &
# % Av
# 2 - 0 - 748
# &
# % Elul
# 3 - 13 - 461
# &\space\\\hline
# \multirow{2}{*}{5849}
# & 5 - 2 - 174
# &
# % Mar\d{h}eshvan
# 6 - 14 - 967
# &
# % Kislev
# 1 - 3 - 680
# &
# % Tevet
# 2 - 16 - 393
# &
# % Shevat
# 4 - 5 - 106
# &
# % Adar
# 5 - 17 - 899
# &\space\\* \space
# &
# % Nisan
# 7 - 6 - 612
# &
# % Iyyar
# 1 - 19 - 325
# &
# % Sivan
# 3 - 8 - 38
# &
# % Tammuz
# 4 - 20 - 831
# &
# % Av
# 6 - 9 - 544
# &
# % Elul
# 7 - 22 - 257
# &\space\\\hline
# \multirow{2}{*}{5850}
# & 2 - 10 - 1050
# &
# % Mar\d{h}eshvan
# 3 - 23 - 763
# &
# % Kislev
# 5 - 12 - 476
# &
# % Tevet
# 7 - 1 - 189
# &
# % Shevat
# 1 - 13 - 982
# &
# % Adar I
# 3 - 2 - 695
# &
# % Adar II
# 4 - 15 - 408
# \\* \space
# &
# % Nisan
# 6 - 4 - 121
# &
# % Iyyar
# 7 - 16 - 914
# &
# % Sivan
# 2 - 5 - 627
# &
# % Tammuz
# 3 - 18 - 340
# &
# % Av
# 5 - 7 - 53
# &
# % Elul
# 6 - 19 - 846
# &\space\\\hline
# \multirow{2}{*}{5851}
# & 1 - 8 - 559
# &
# % Mar\d{h}eshvan
# 2 - 21 - 272
# &
# % Kislev
# 4 - 9 - 1065
# &
# % Tevet
# 5 - 22 - 778
# &
# % Shevat
# 7 - 11 - 491
# &
# % Adar
# 2 - 0 - 204
# &\space\\* \space
# &
# % Nisan
# 3 - 12 - 997
# &
# % Iyyar
# 5 - 1 - 710
# &
# % Sivan
# 6 - 14 - 423
# &
# % Tammuz
# 1 - 3 - 136
# &
# % Av
# 2 - 15 - 929
# &
# % Elul
# 4 - 4 - 642
# &\space\\\hline
# \multirow{2}{*}{5852}
# & 5 - 17 - 355
# &
# % Mar\d{h}eshvan
# 7 - 6 - 68
# &
# % Kislev
# 1 - 18 - 861
# &
# % Tevet
# 3 - 7 - 574
# &
# % Shevat
# 4 - 20 - 287
# &
# % Adar I
# 6 - 9 - 0
# &
# % Adar II
# 7 - 21 - 793
# \\* \space
# &
# % Nisan
# 2 - 10 - 506
# &
# % Iyyar
# 3 - 23 - 219
# &
# % Sivan
# 5 - 11 - 1012
# &
# % Tammuz
# 7 - 0 - 725
# &
# % Av
# 1 - 13 - 438
# &
# % Elul
# 3 - 2 - 151
# &\space\\\hline
# \multirow{2}{*}{5853}
# & 4 - 14 - 944
# &
# % Mar\d{h}eshvan
# 6 - 3 - 657
# &
# % Kislev
# 7 - 16 - 370
# &
# % Tevet
# 2 - 5 - 83
# &
# % Shevat
# 3 - 17 - 876
# &
# % Adar
# 5 - 6 - 589
# &\space\\* \space
# &
# % Nisan
# 6 - 19 - 302
# &
# % Iyyar
# 1 - 8 - 15
# &
# % Sivan
# 2 - 20 - 808
# &
# % Tammuz
# 4 - 9 - 521
# &
# % Av
# 5 - 22 - 234
# &
# % Elul
# 7 - 10 - 1027
# &\space\\\hline
# \multirow{2}{*}{5854}
# & 1 - 23 - 740
# &
# % Mar\d{h}eshvan
# 3 - 12 - 453
# &
# % Kislev
# 5 - 1 - 166
# &
# % Tevet
# 6 - 13 - 959
# &
# % Shevat
# 1 - 2 - 672
# &
# % Adar
# 2 - 15 - 385
# &\space\\* \space
# &
# % Nisan
# 4 - 4 - 98
# &
# % Iyyar
# 5 - 16 - 891
# &
# % Sivan
# 7 - 5 - 604
# &
# % Tammuz
# 1 - 18 - 317
# &
# % Av
# 3 - 7 - 30
# &
# % Elul
# 4 - 19 - 823
# &\space\\\hline
# \multirow{2}{*}{5855}
# & 6 - 8 - 536
# &
# % Mar\d{h}eshvan
# 7 - 21 - 249
# &
# % Kislev
# 2 - 9 - 1042
# &
# % Tevet
# 3 - 22 - 755
# &
# % Shevat
# 5 - 11 - 468
# &
# % Adar I
# 7 - 0 - 181
# &
# % Adar II
# 1 - 12 - 974
# \\* \space
# &
# % Nisan
# 3 - 1 - 687
# &
# % Iyyar
# 4 - 14 - 400
# &
# % Sivan
# 6 - 3 - 113
# &
# % Tammuz
# 7 - 15 - 906
# &
# % Av
# 2 - 4 - 619
# &
# % Elul
# 3 - 17 - 332
# &\space\\\hline
# \multirow{2}{*}{5856}
# & 5 - 6 - 45
# &
# % Mar\d{h}eshvan
# 6 - 18 - 838
# &
# % Kislev
# 1 - 7 - 551
# &
# % Tevet
# 2 - 20 - 264
# &
# % Shevat
# 4 - 8 - 1057
# &
# % Adar
# 5 - 21 - 770
# &\space\\* \space
# &
# % Nisan
# 7 - 10 - 483
# &
# % Iyyar
# 1 - 23 - 196
# &
# % Sivan
# 3 - 11 - 989
# &
# % Tammuz
# 5 - 0 - 702
# &
# % Av
# 6 - 13 - 415
# &
# % Elul
# 1 - 2 - 128
# &\space\\\hline
# \multirow{2}{*}{5857}
# & 2 - 14 - 921
# &
# % Mar\d{h}eshvan
# 4 - 3 - 634
# &
# % Kislev
# 5 - 16 - 347
# &
# % Tevet
# 7 - 5 - 60
# &
# % Shevat
# 1 - 17 - 853
# &
# % Adar
# 3 - 6 - 566
# &\space\\* \space
# &
# % Nisan
# 4 - 19 - 279
# &
# % Iyyar
# 6 - 7 - 1072
# &
# % Sivan
# 7 - 20 - 785
# &
# % Tammuz
# 2 - 9 - 498
# &
# % Av
# 3 - 22 - 211
# &
# % Elul
# 5 - 10 - 1004
# &\space\\\hline
# \multirow{2}{*}{5858}
# & 6 - 23 - 717
# &
# % Mar\d{h}eshvan
# 1 - 12 - 430
# &
# % Kislev
# 3 - 1 - 143
# &
# % Tevet
# 4 - 13 - 936
# &
# % Shevat
# 6 - 2 - 649
# &
# % Adar I
# 7 - 15 - 362
# &
# % Adar II
# 2 - 4 - 75
# \\* \space
# &
# % Nisan
# 3 - 16 - 868
# &
# % Iyyar
# 5 - 5 - 581
# &
# % Sivan
# 6 - 18 - 294
# &
# % Tammuz
# 1 - 7 - 7
# &
# % Av
# 2 - 19 - 800
# &
# % Elul
# 4 - 8 - 513
# &\space\\\hline
# \multirow{2}{*}{5859}
# & 5 - 21 - 226
# &
# % Mar\d{h}eshvan
# 7 - 9 - 1019
# &
# % Kislev
# 1 - 22 - 732
# &
# % Tevet
# 3 - 11 - 445
# &
# % Shevat
# 5 - 0 - 158
# &
# % Adar
# 6 - 12 - 951
# &\space\\* \space
# &
# % Nisan
# 1 - 1 - 664
# &
# % Iyyar
# 2 - 14 - 377
# &
# % Sivan
# 4 - 3 - 90
# &
# % Tammuz
# 5 - 15 - 883
# &
# % Av
# 7 - 4 - 596
# &
# % Elul
# 1 - 17 - 309
# &\space\\\hline
# \multirow{2}{*}{5860}
# & 3 - 6 - 22
# &
# % Mar\d{h}eshvan
# 4 - 18 - 815
# &
# % Kislev
# 6 - 7 - 528
# &
# % Tevet
# 7 - 20 - 241
# &
# % Shevat
# 2 - 8 - 1034
# &
# % Adar I
# 3 - 21 - 747
# &
# % Adar II
# 5 - 10 - 460
# \\* \space
# &
# % Nisan
# 6 - 23 - 173
# &
# % Iyyar
# 1 - 11 - 966
# &
# % Sivan
# 3 - 0 - 679
# &
# % Tammuz
# 4 - 13 - 392
# &
# % Av
# 6 - 2 - 105
# &
# % Elul
# 7 - 14 - 898
# &\space\\\hline
# \multirow{2}{*}{5861}
# & 2 - 3 - 611
# &
# % Mar\d{h}eshvan
# 3 - 16 - 324
# &
# % Kislev
# 5 - 5 - 37
# &
# % Tevet
# 6 - 17 - 830
# &
# % Shevat
# 1 - 6 - 543
# &
# % Adar
# 2 - 19 - 256
# &\space\\* \space
# &
# % Nisan
# 4 - 7 - 1049
# &
# % Iyyar
# 5 - 20 - 762
# &
# % Sivan
# 7 - 9 - 475
# &
# % Tammuz
# 1 - 22 - 188
# &
# % Av
# 3 - 10 - 981
# &
# % Elul
# 4 - 23 - 694
# &\space\\\hline
# \multirow{2}{*}{5862}
# & 6 - 12 - 407
# &
# % Mar\d{h}eshvan
# 1 - 1 - 120
# &
# % Kislev
# 2 - 13 - 913
# &
# % Tevet
# 4 - 2 - 626
# &
# % Shevat
# 5 - 15 - 339
# &
# % Adar
# 7 - 4 - 52
# &\space\\* \space
# &
# % Nisan
# 1 - 16 - 845
# &
# % Iyyar
# 3 - 5 - 558
# &
# % Sivan
# 4 - 18 - 271
# &
# % Tammuz
# 6 - 6 - 1064
# &
# % Av
# 7 - 19 - 777
# &
# % Elul
# 2 - 8 - 490
# &\space\\\hline
# \multirow{2}{*}{5863}
# & 3 - 21 - 203
# &
# % Mar\d{h}eshvan
# 5 - 9 - 996
# &
# % Kislev
# 6 - 22 - 709
# &
# % Tevet
# 1 - 11 - 422
# &
# % Shevat
# 3 - 0 - 135
# &
# % Adar I
# 4 - 12 - 928
# &
# % Adar II
# 6 - 1 - 641
# \\* \space
# &
# % Nisan
# 7 - 14 - 354
# &
# % Iyyar
# 2 - 3 - 67
# &
# % Sivan
# 3 - 15 - 860
# &
# % Tammuz
# 5 - 4 - 573
# &
# % Av
# 6 - 17 - 286
# &
# % Elul
# 1 - 5 - 1079
# &\space\\\hline
# \multirow{2}{*}{5864}
# & 2 - 18 - 792
# &
# % Mar\d{h}eshvan
# 4 - 7 - 505
# &
# % Kislev
# 5 - 20 - 218
# &
# % Tevet
# 7 - 8 - 1011
# &
# % Shevat
# 1 - 21 - 724
# &
# % Adar
# 3 - 10 - 437
# &\space\\* \space
# &
# % Nisan
# 4 - 23 - 150
# &
# % Iyyar
# 6 - 11 - 943
# &
# % Sivan
# 1 - 0 - 656
# &
# % Tammuz
# 2 - 13 - 369
# &
# % Av
# 4 - 2 - 82
# &
# % Elul
# 5 - 14 - 875
# &\space\\\hline
# \multirow{2}{*}{5865}
# & 7 - 3 - 588
# &
# % Mar\d{h}eshvan
# 1 - 16 - 301
# &
# % Kislev
# 3 - 5 - 14
# &
# % Tevet
# 4 - 17 - 807
# &
# % Shevat
# 6 - 6 - 520
# &
# % Adar
# 7 - 19 - 233
# &\space\\* \space
# &
# % Nisan
# 2 - 7 - 1026
# &
# % Iyyar
# 3 - 20 - 739
# &
# % Sivan
# 5 - 9 - 452
# &
# % Tammuz
# 6 - 22 - 165
# &
# % Av
# 1 - 10 - 958
# &
# % Elul
# 2 - 23 - 671
# &\space\\\hline
# \multirow{2}{*}{5866}
# & 4 - 12 - 384
# &
# % Mar\d{h}eshvan
# 6 - 1 - 97
# &
# % Kislev
# 7 - 13 - 890
# &
# % Tevet
# 2 - 2 - 603
# &
# % Shevat
# 3 - 15 - 316
# &
# % Adar I
# 5 - 4 - 29
# &
# % Adar II
# 6 - 16 - 822
# \\* \space
# &
# % Nisan
# 1 - 5 - 535
# &
# % Iyyar
# 2 - 18 - 248
# &
# % Sivan
# 4 - 6 - 1041
# &
# % Tammuz
# 5 - 19 - 754
# &
# % Av
# 7 - 8 - 467
# &
# % Elul
# 1 - 21 - 180
# &\space\\\hline
# \multirow{2}{*}{5867}
# & 3 - 9 - 973
# &
# % Mar\d{h}eshvan
# 4 - 22 - 686
# &
# % Kislev
# 6 - 11 - 399
# &
# % Tevet
# 1 - 0 - 112
# &
# % Shevat
# 2 - 12 - 905
# &
# % Adar
# 4 - 1 - 618
# &\space\\* \space
# &
# % Nisan
# 5 - 14 - 331
# &
# % Iyyar
# 7 - 3 - 44
# &
# % Sivan
# 1 - 15 - 837
# &
# % Tammuz
# 3 - 4 - 550
# &
# % Av
# 4 - 17 - 263
# &
# % Elul
# 6 - 5 - 1056
# &\space\\\hline
# \multirow{2}{*}{5868}
# & 7 - 18 - 769
# &
# % Mar\d{h}eshvan
# 2 - 7 - 482
# &
# % Kislev
# 3 - 20 - 195
# &
# % Tevet
# 5 - 8 - 988
# &
# % Shevat
# 6 - 21 - 701
# &
# % Adar
# 1 - 10 - 414
# &\space\\* \space
# &
# % Nisan
# 2 - 23 - 127
# &
# % Iyyar
# 4 - 11 - 920
# &
# % Sivan
# 6 - 0 - 633
# &
# % Tammuz
# 7 - 13 - 346
# &
# % Av
# 2 - 2 - 59
# &
# % Elul
# 3 - 14 - 852
# &\space\\\hline
# \multirow{2}{*}{5869}
# & 5 - 3 - 565
# &
# % Mar\d{h}eshvan
# 6 - 16 - 278
# &
# % Kislev
# 1 - 4 - 1071
# &
# % Tevet
# 2 - 17 - 784
# &
# % Shevat
# 4 - 6 - 497
# &
# % Adar I
# 5 - 19 - 210
# &
# % Adar II
# 7 - 7 - 1003
# \\* \space
# &
# % Nisan
# 1 - 20 - 716
# &
# % Iyyar
# 3 - 9 - 429
# &
# % Sivan
# 4 - 22 - 142
# &
# % Tammuz
# 6 - 10 - 935
# &
# % Av
# 7 - 23 - 648
# &
# % Elul
# 2 - 12 - 361
# &\space\\\hline
# \multirow{2}{*}{5870}
# & 4 - 1 - 74
# &
# % Mar\d{h}eshvan
# 5 - 13 - 867
# &
# % Kislev
# 7 - 2 - 580
# &
# % Tevet
# 1 - 15 - 293
# &
# % Shevat
# 3 - 4 - 6
# &
# % Adar
# 4 - 16 - 799
# &\space\\* \space
# &
# % Nisan
# 6 - 5 - 512
# &
# % Iyyar
# 7 - 18 - 225
# &
# % Sivan
# 2 - 6 - 1018
# &
# % Tammuz
# 3 - 19 - 731
# &
# % Av
# 5 - 8 - 444
# &
# % Elul
# 6 - 21 - 157
# &\space\\\hline
# \multirow{2}{*}{5871}
# & 1 - 9 - 950
# &
# % Mar\d{h}eshvan
# 2 - 22 - 663
# &
# % Kislev
# 4 - 11 - 376
# &
# % Tevet
# 6 - 0 - 89
# &
# % Shevat
# 7 - 12 - 882
# &
# % Adar I
# 2 - 1 - 595
# &
# % Adar II
# 3 - 14 - 308
# \\* \space
# &
# % Nisan
# 5 - 3 - 21
# &
# % Iyyar
# 6 - 15 - 814
# &
# % Sivan
# 1 - 4 - 527
# &
# % Tammuz
# 2 - 17 - 240
# &
# % Av
# 4 - 5 - 1033
# &
# % Elul
# 5 - 18 - 746
# &\space\\\hline
# \multirow{2}{*}{5872}
# & 7 - 7 - 459
# &
# % Mar\d{h}eshvan
# 1 - 20 - 172
# &
# % Kislev
# 3 - 8 - 965
# &
# % Tevet
# 4 - 21 - 678
# &
# % Shevat
# 6 - 10 - 391
# &
# % Adar
# 7 - 23 - 104
# &\space\\* \space
# &
# % Nisan
# 2 - 11 - 897
# &
# % Iyyar
# 4 - 0 - 610
# &
# % Sivan
# 5 - 13 - 323
# &
# % Tammuz
# 7 - 2 - 36
# &
# % Av
# 1 - 14 - 829
# &
# % Elul
# 3 - 3 - 542
# &\space\\\hline
# \multirow{2}{*}{5873}
# & 4 - 16 - 255
# &
# % Mar\d{h}eshvan
# 6 - 4 - 1048
# &
# % Kislev
# 7 - 17 - 761
# &
# % Tevet
# 2 - 6 - 474
# &
# % Shevat
# 3 - 19 - 187
# &
# % Adar
# 5 - 7 - 980
# &\space\\* \space
# &
# % Nisan
# 6 - 20 - 693
# &
# % Iyyar
# 1 - 9 - 406
# &
# % Sivan
# 2 - 22 - 119
# &
# % Tammuz
# 4 - 10 - 912
# &
# % Av
# 5 - 23 - 625
# &
# % Elul
# 7 - 12 - 338
# &\space\\\hline
# \multirow{2}{*}{5874}
# & 2 - 1 - 51
# &
# % Mar\d{h}eshvan
# 3 - 13 - 844
# &
# % Kislev
# 5 - 2 - 557
# &
# % Tevet
# 6 - 15 - 270
# &
# % Shevat
# 1 - 3 - 1063
# &
# % Adar I
# 2 - 16 - 776
# &
# % Adar II
# 4 - 5 - 489
# \\* \space
# &
# % Nisan
# 5 - 18 - 202
# &
# % Iyyar
# 7 - 6 - 995
# &
# % Sivan
# 1 - 19 - 708
# &
# % Tammuz
# 3 - 8 - 421
# &
# % Av
# 4 - 21 - 134
# &
# % Elul
# 6 - 9 - 927
# &\space\\\hline
# \multirow{2}{*}{5875}
# & 7 - 22 - 640
# &
# % Mar\d{h}eshvan
# 2 - 11 - 353
# &
# % Kislev
# 4 - 0 - 66
# &
# % Tevet
# 5 - 12 - 859
# &
# % Shevat
# 7 - 1 - 572
# &
# % Adar
# 1 - 14 - 285
# &\space\\* \space
# &
# % Nisan
# 3 - 2 - 1078
# &
# % Iyyar
# 4 - 15 - 791
# &
# % Sivan
# 6 - 4 - 504
# &
# % Tammuz
# 7 - 17 - 217
# &
# % Av
# 2 - 5 - 1010
# &
# % Elul
# 3 - 18 - 723
# &\space\\\hline
# \multirow{2}{*}{5876}
# & 5 - 7 - 436
# &
# % Mar\d{h}eshvan
# 6 - 20 - 149
# &
# % Kislev
# 1 - 8 - 942
# &
# % Tevet
# 2 - 21 - 655
# &
# % Shevat
# 4 - 10 - 368
# &
# % Adar
# 5 - 23 - 81
# &\space\\* \space
# &
# % Nisan
# 7 - 11 - 874
# &
# % Iyyar
# 2 - 0 - 587
# &
# % Sivan
# 3 - 13 - 300
# &
# % Tammuz
# 5 - 2 - 13
# &
# % Av
# 6 - 14 - 806
# &
# % Elul
# 1 - 3 - 519
# &\space\\\hline
# \multirow{2}{*}{5877}
# & 2 - 16 - 232
# &
# % Mar\d{h}eshvan
# 4 - 4 - 1025
# &
# % Kislev
# 5 - 17 - 738
# &
# % Tevet
# 7 - 6 - 451
# &
# % Shevat
# 1 - 19 - 164
# &
# % Adar I
# 3 - 7 - 957
# &
# % Adar II
# 4 - 20 - 670
# \\* \space
# &
# % Nisan
# 6 - 9 - 383
# &
# % Iyyar
# 7 - 22 - 96
# &
# % Sivan
# 2 - 10 - 889
# &
# % Tammuz
# 3 - 23 - 602
# &
# % Av
# 5 - 12 - 315
# &
# % Elul
# 7 - 1 - 28
# &\space\\\hline
# \multirow{2}{*}{5878}
# & 1 - 13 - 821
# &
# % Mar\d{h}eshvan
# 3 - 2 - 534
# &
# % Kislev
# 4 - 15 - 247
# &
# % Tevet
# 6 - 3 - 1040
# &
# % Shevat
# 7 - 16 - 753
# &
# % Adar
# 2 - 5 - 466
# &\space\\* \space
# &
# % Nisan
# 3 - 18 - 179
# &
# % Iyyar
# 5 - 6 - 972
# &
# % Sivan
# 6 - 19 - 685
# &
# % Tammuz
# 1 - 8 - 398
# &
# % Av
# 2 - 21 - 111
# &
# % Elul
# 4 - 9 - 904
# &\space\\\hline
# \multirow{2}{*}{5879}
# & 5 - 22 - 617
# &
# % Mar\d{h}eshvan
# 7 - 11 - 330
# &
# % Kislev
# 2 - 0 - 43
# &
# % Tevet
# 3 - 12 - 836
# &
# % Shevat
# 5 - 1 - 549
# &
# % Adar I
# 6 - 14 - 262
# &
# % Adar II
# 1 - 2 - 1055
# \\* \space
# &
# % Nisan
# 2 - 15 - 768
# &
# % Iyyar
# 4 - 4 - 481
# &
# % Sivan
# 5 - 17 - 194
# &
# % Tammuz
# 7 - 5 - 987
# &
# % Av
# 1 - 18 - 700
# &
# % Elul
# 3 - 7 - 413
# &\space\\\hline
# \multirow{2}{*}{5880}
# & 4 - 20 - 126
# &
# % Mar\d{h}eshvan
# 6 - 8 - 919
# &
# % Kislev
# 7 - 21 - 632
# &
# % Tevet
# 2 - 10 - 345
# &
# % Shevat
# 3 - 23 - 58
# &
# % Adar
# 5 - 11 - 851
# &\space\\* \space
# &
# % Nisan
# 7 - 0 - 564
# &
# % Iyyar
# 1 - 13 - 277
# &
# % Sivan
# 3 - 1 - 1070
# &
# % Tammuz
# 4 - 14 - 783
# &
# % Av
# 6 - 3 - 496
# &
# % Elul
# 7 - 16 - 209
# &\space\\\hline
# \multirow{2}{*}{5881}
# & 2 - 4 - 1002
# &
# % Mar\d{h}eshvan
# 3 - 17 - 715
# &
# % Kislev
# 5 - 6 - 428
# &
# % Tevet
# 6 - 19 - 141
# &
# % Shevat
# 1 - 7 - 934
# &
# % Adar
# 2 - 20 - 647
# &\space\\* \space
# &
# % Nisan
# 4 - 9 - 360
# &
# % Iyyar
# 5 - 22 - 73
# &
# % Sivan
# 7 - 10 - 866
# &
# % Tammuz
# 1 - 23 - 579
# &
# % Av
# 3 - 12 - 292
# &
# % Elul
# 5 - 1 - 5
# &\space\\\hline
# \multirow{2}{*}{5882}
# & 6 - 13 - 798
# &
# % Mar\d{h}eshvan
# 1 - 2 - 511
# &
# % Kislev
# 2 - 15 - 224
# &
# % Tevet
# 4 - 3 - 1017
# &
# % Shevat
# 5 - 16 - 730
# &
# % Adar I
# 7 - 5 - 443
# &
# % Adar II
# 1 - 18 - 156
# \\* \space
# &
# % Nisan
# 3 - 6 - 949
# &
# % Iyyar
# 4 - 19 - 662
# &
# % Sivan
# 6 - 8 - 375
# &
# % Tammuz
# 7 - 21 - 88
# &
# % Av
# 2 - 9 - 881
# &
# % Elul
# 3 - 22 - 594
# &\space\\\hline
# \multirow{2}{*}{5883}
# & 5 - 11 - 307
# &
# % Mar\d{h}eshvan
# 7 - 0 - 20
# &
# % Kislev
# 1 - 12 - 813
# &
# % Tevet
# 3 - 1 - 526
# &
# % Shevat
# 4 - 14 - 239
# &
# % Adar
# 6 - 2 - 1032
# &\space\\* \space
# &
# % Nisan
# 7 - 15 - 745
# &
# % Iyyar
# 2 - 4 - 458
# &
# % Sivan
# 3 - 17 - 171
# &
# % Tammuz
# 5 - 5 - 964
# &
# % Av
# 6 - 18 - 677
# &
# % Elul
# 1 - 7 - 390
# &\space\\\hline
# \multirow{2}{*}{5884}
# & 2 - 20 - 103
# &
# % Mar\d{h}eshvan
# 4 - 8 - 896
# &
# % Kislev
# 5 - 21 - 609
# &
# % Tevet
# 7 - 10 - 322
# &
# % Shevat
# 1 - 23 - 35
# &
# % Adar
# 3 - 11 - 828
# &\space\\* \space
# &
# % Nisan
# 5 - 0 - 541
# &
# % Iyyar
# 6 - 13 - 254
# &
# % Sivan
# 1 - 1 - 1047
# &
# % Tammuz
# 2 - 14 - 760
# &
# % Av
# 4 - 3 - 473
# &
# % Elul
# 5 - 16 - 186
# &\space\\\hline
# \multirow{2}{*}{5885}
# & 7 - 4 - 979
# &
# % Mar\d{h}eshvan
# 1 - 17 - 692
# &
# % Kislev
# 3 - 6 - 405
# &
# % Tevet
# 4 - 19 - 118
# &
# % Shevat
# 6 - 7 - 911
# &
# % Adar I
# 7 - 20 - 624
# &
# % Adar II
# 2 - 9 - 337
# \\* \space
# &
# % Nisan
# 3 - 22 - 50
# &
# % Iyyar
# 5 - 10 - 843
# &
# % Sivan
# 6 - 23 - 556
# &
# % Tammuz
# 1 - 12 - 269
# &
# % Av
# 3 - 0 - 1062
# &
# % Elul
# 4 - 13 - 775
# &\space\\\hline
# \multirow{2}{*}{5886}
# & 6 - 2 - 488
# &
# % Mar\d{h}eshvan
# 7 - 15 - 201
# &
# % Kislev
# 2 - 3 - 994
# &
# % Tevet
# 3 - 16 - 707
# &
# % Shevat
# 5 - 5 - 420
# &
# % Adar
# 6 - 18 - 133
# &\space\\* \space
# &
# % Nisan
# 1 - 6 - 926
# &
# % Iyyar
# 2 - 19 - 639
# &
# % Sivan
# 4 - 8 - 352
# &
# % Tammuz
# 5 - 21 - 65
# &
# % Av
# 7 - 9 - 858
# &
# % Elul
# 1 - 22 - 571
# &\space\\\hline
# \multirow{2}{*}{5887}
# & 3 - 11 - 284
# &
# % Mar\d{h}eshvan
# 4 - 23 - 1077
# &
# % Kislev
# 6 - 12 - 790
# &
# % Tevet
# 1 - 1 - 503
# &
# % Shevat
# 2 - 14 - 216
# &
# % Adar
# 4 - 2 - 1009
# &\space\\* \space
# &
# % Nisan
# 5 - 15 - 722
# &
# % Iyyar
# 7 - 4 - 435
# &
# % Sivan
# 1 - 17 - 148
# &
# % Tammuz
# 3 - 5 - 941
# &
# % Av
# 4 - 18 - 654
# &
# % Elul
# 6 - 7 - 367
# &\space\\\hline
# \multirow{2}{*}{5888}
# & 7 - 20 - 80
# &
# % Mar\d{h}eshvan
# 2 - 8 - 873
# &
# % Kislev
# 3 - 21 - 586
# &
# % Tevet
# 5 - 10 - 299
# &
# % Shevat
# 6 - 23 - 12
# &
# % Adar I
# 1 - 11 - 805
# &
# % Adar II
# 3 - 0 - 518
# \\* \space
# &
# % Nisan
# 4 - 13 - 231
# &
# % Iyyar
# 6 - 1 - 1024
# &
# % Sivan
# 7 - 14 - 737
# &
# % Tammuz
# 2 - 3 - 450
# &
# % Av
# 3 - 16 - 163
# &
# % Elul
# 5 - 4 - 956
# &\space\\\hline
# \multirow{2}{*}{5889}
# & 6 - 17 - 669
# &
# % Mar\d{h}eshvan
# 1 - 6 - 382
# &
# % Kislev
# 2 - 19 - 95
# &
# % Tevet
# 4 - 7 - 888
# &
# % Shevat
# 5 - 20 - 601
# &
# % Adar
# 7 - 9 - 314
# &\space\\* \space
# &
# % Nisan
# 1 - 22 - 27
# &
# % Iyyar
# 3 - 10 - 820
# &
# % Sivan
# 4 - 23 - 533
# &
# % Tammuz
# 6 - 12 - 246
# &
# % Av
# 1 - 0 - 1039
# &
# % Elul
# 2 - 13 - 752
# &\space\\\hline
# \multirow{2}{*}{5890}
# & 4 - 2 - 465
# &
# % Mar\d{h}eshvan
# 5 - 15 - 178
# &
# % Kislev
# 7 - 3 - 971
# &
# % Tevet
# 1 - 16 - 684
# &
# % Shevat
# 3 - 5 - 397
# &
# % Adar I
# 4 - 18 - 110
# &
# % Adar II
# 6 - 6 - 903
# \\* \space
# &
# % Nisan
# 7 - 19 - 616
# &
# % Iyyar
# 2 - 8 - 329
# &
# % Sivan
# 3 - 21 - 42
# &
# % Tammuz
# 5 - 9 - 835
# &
# % Av
# 6 - 22 - 548
# &
# % Elul
# 1 - 11 - 261
# &\space\\\hline
# \multirow{2}{*}{5891}
# & 2 - 23 - 1054
# &
# % Mar\d{h}eshvan
# 4 - 12 - 767
# &
# % Kislev
# 6 - 1 - 480
# &
# % Tevet
# 7 - 14 - 193
# &
# % Shevat
# 2 - 2 - 986
# &
# % Adar
# 3 - 15 - 699
# &\space\\* \space
# &
# % Nisan
# 5 - 4 - 412
# &
# % Iyyar
# 6 - 17 - 125
# &
# % Sivan
# 1 - 5 - 918
# &
# % Tammuz
# 2 - 18 - 631
# &
# % Av
# 4 - 7 - 344
# &
# % Elul
# 5 - 20 - 57
# &\space\\\hline
# \multirow{2}{*}{5892}
# & 7 - 8 - 850
# &
# % Mar\d{h}eshvan
# 1 - 21 - 563
# &
# % Kislev
# 3 - 10 - 276
# &
# % Tevet
# 4 - 22 - 1069
# &
# % Shevat
# 6 - 11 - 782
# &
# % Adar
# 1 - 0 - 495
# &\space\\* \space
# &
# % Nisan
# 2 - 13 - 208
# &
# % Iyyar
# 4 - 1 - 1001
# &
# % Sivan
# 5 - 14 - 714
# &
# % Tammuz
# 7 - 3 - 427
# &
# % Av
# 1 - 16 - 140
# &
# % Elul
# 3 - 4 - 933
# &\space\\\hline
# \multirow{2}{*}{5893}
# & 4 - 17 - 646
# &
# % Mar\d{h}eshvan
# 6 - 6 - 359
# &
# % Kislev
# 7 - 19 - 72
# &
# % Tevet
# 2 - 7 - 865
# &
# % Shevat
# 3 - 20 - 578
# &
# % Adar I
# 5 - 9 - 291
# &
# % Adar II
# 6 - 22 - 4
# \\* \space
# &
# % Nisan
# 1 - 10 - 797
# &
# % Iyyar
# 2 - 23 - 510
# &
# % Sivan
# 4 - 12 - 223
# &
# % Tammuz
# 6 - 0 - 1016
# &
# % Av
# 7 - 13 - 729
# &
# % Elul
# 2 - 2 - 442
# &\space\\\hline
# \multirow{2}{*}{5894}
# & 3 - 15 - 155
# &
# % Mar\d{h}eshvan
# 5 - 3 - 948
# &
# % Kislev
# 6 - 16 - 661
# &
# % Tevet
# 1 - 5 - 374
# &
# % Shevat
# 2 - 18 - 87
# &
# % Adar
# 4 - 6 - 880
# &\space\\* \space
# &
# % Nisan
# 5 - 19 - 593
# &
# % Iyyar
# 7 - 8 - 306
# &
# % Sivan
# 1 - 21 - 19
# &
# % Tammuz
# 3 - 9 - 812
# &
# % Av
# 4 - 22 - 525
# &
# % Elul
# 6 - 11 - 238
# &\space\\\hline
# \multirow{2}{*}{5895}
# & 7 - 23 - 1031
# &
# % Mar\d{h}eshvan
# 2 - 12 - 744
# &
# % Kislev
# 4 - 1 - 457
# &
# % Tevet
# 5 - 14 - 170
# &
# % Shevat
# 7 - 2 - 963
# &
# % Adar
# 1 - 15 - 676
# &\space\\* \space
# &
# % Nisan
# 3 - 4 - 389
# &
# % Iyyar
# 4 - 17 - 102
# &
# % Sivan
# 6 - 5 - 895
# &
# % Tammuz
# 7 - 18 - 608
# &
# % Av
# 2 - 7 - 321
# &
# % Elul
# 3 - 20 - 34
# &\space\\\hline
# \multirow{2}{*}{5896}
# & 5 - 8 - 827
# &
# % Mar\d{h}eshvan
# 6 - 21 - 540
# &
# % Kislev
# 1 - 10 - 253
# &
# % Tevet
# 2 - 22 - 1046
# &
# % Shevat
# 4 - 11 - 759
# &
# % Adar I
# 6 - 0 - 472
# &
# % Adar II
# 7 - 13 - 185
# \\* \space
# &
# % Nisan
# 2 - 1 - 978
# &
# % Iyyar
# 3 - 14 - 691
# &
# % Sivan
# 5 - 3 - 404
# &
# % Tammuz
# 6 - 16 - 117
# &
# % Av
# 1 - 4 - 910
# &
# % Elul
# 2 - 17 - 623
# &\space\\\hline
# \multirow{2}{*}{5897}
# & 4 - 6 - 336
# &
# % Mar\d{h}eshvan
# 5 - 19 - 49
# &
# % Kislev
# 7 - 7 - 842
# &
# % Tevet
# 1 - 20 - 555
# &
# % Shevat
# 3 - 9 - 268
# &
# % Adar
# 4 - 21 - 1061
# &\space\\* \space
# &
# % Nisan
# 6 - 10 - 774
# &
# % Iyyar
# 7 - 23 - 487
# &
# % Sivan
# 2 - 12 - 200
# &
# % Tammuz
# 4 - 0 - 993
# &
# % Av
# 5 - 13 - 706
# &
# % Elul
# 7 - 2 - 419
# &\space\\\hline
# \multirow{2}{*}{5898}
# & 1 - 15 - 132
# &
# % Mar\d{h}eshvan
# 3 - 3 - 925
# &
# % Kislev
# 4 - 16 - 638
# &
# % Tevet
# 6 - 5 - 351
# &
# % Shevat
# 7 - 18 - 64
# &
# % Adar I
# 2 - 6 - 857
# &
# % Adar II
# 3 - 19 - 570
# \\* \space
# &
# % Nisan
# 5 - 8 - 283
# &
# % Iyyar
# 6 - 20 - 1076
# &
# % Sivan
# 1 - 9 - 789
# &
# % Tammuz
# 2 - 22 - 502
# &
# % Av
# 4 - 11 - 215
# &
# % Elul
# 5 - 23 - 1008
# &\space\\\hline
# \multirow{2}{*}{5899}
# & 7 - 12 - 721
# &
# % Mar\d{h}eshvan
# 2 - 1 - 434
# &
# % Kislev
# 3 - 14 - 147
# &
# % Tevet
# 5 - 2 - 940
# &
# % Shevat
# 6 - 15 - 653
# &
# % Adar
# 1 - 4 - 366
# &\space\\* \space
# &
# % Nisan
# 2 - 17 - 79
# &
# % Iyyar
# 4 - 5 - 872
# &
# % Sivan
# 5 - 18 - 585
# &
# % Tammuz
# 7 - 7 - 298
# &
# % Av
# 1 - 20 - 11
# &
# % Elul
# 3 - 8 - 804
# &\space\\\hline
